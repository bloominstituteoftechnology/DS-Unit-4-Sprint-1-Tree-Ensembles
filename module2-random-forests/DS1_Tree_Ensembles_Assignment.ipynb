# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyasJothish/DS-Unit-4-Sprint-1-Tree-Ensembles/blob/master/module2-random-forests/DS1_Tree_Ensembles_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

from google.colab import drive
drive.mount('/content/drive')
# %env KAGGLE_CONFIG_DIR=/content/drive/My Drive/
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.3)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.22)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2019.3.9)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.18.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.28.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (3.0.0)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: text-unidecode==1.2 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# env: KAGGLE_CONFIG_DIR=/content/drive/My Drive/

# %%
# You also have to join the Titanic competition to have access to the data
# !kaggle competitions download -c ds1-tree-ensembles
# Out:
# train_features.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# train_labels.csv: Skipping, found more recently modified local copy (use --force to force download)
# test_features.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# LCDataDictionary.xlsx: Skipping, found more recently modified local copy (use --force to force download)

# %%
#!unzip train_features.csv.zip
#!unzip test_features.csv.zip

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.6/dist-packages (1.3.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.1.0)
# Requirement already satisfied: pandas>=0.20.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.22.0)
# Requirement already satisfied: statsmodels>=0.6.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.8.0)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.14.6)
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.20.3)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.1->category_encoders) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.1->category_encoders) (2018.9)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.4.1->category_encoders) (1.11.0)

# %%
# Generic imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
X_train = pd.read_csv("train_features.csv")
y_train = pd.read_csv("train_labels.csv")['charged_off']
print(X_train.shape)
print(y_train.shape)
# Out:
# (37745, 103)
# (37745,)

# %%
pd.set_option('display.max_columns', None)  # Unlimited columns
pd.set_option('display.max_rows', None)  # Unlimited rows

# %%
X_train.isnull().sum()
# Out:
# id                                         0
# member_id                              37745
# loan_amnt                                  0
# funded_amnt                                0
# term                                       0
# int_rate                                   0
# installment                                0
# grade                                      0
# sub_grade                                  0
# emp_title                               3565
# emp_length                              3277
# home_ownership                             0
# annual_inc                                 0
# url                                    37745
# desc                                   37745
# purpose                                    0
# title                                      0
# zip_code                                   0
# addr_state                                 0
# dti                                       92
# delinq_2yrs                                0
# earliest_cr_line                           0
# inq_last_6mths                             0
# mths_since_last_delinq                 20881
# mths_since_last_record                 32170
# open_acc                                   0
# pub_rec                                    0
# revol_bal                                  0
# revol_util                                53
# total_acc                                  0
# initial_list_status                        0
# collections_12_mths_ex_med                 0
# mths_since_last_major_derog            28640
# application_type                           0
# annual_inc_joint                       33007
# dti_joint                              33007
# acc_now_delinq                             0
# tot_coll_amt                               0
# tot_cur_bal                                0
# open_acc_6m                                0
# open_act_il                                0
# open_il_12m                                0
# open_il_24m                                0
# mths_since_rcnt_il                      1234
# total_bal_il                               0
# il_util                                 6255
# open_rv_12m                                0
# open_rv_24m                                0
# max_bal_bc                                 0
# all_util                                  13
# total_rev_hi_lim                           0
# inq_fi                                     0
# total_cu_tl                                0
# inq_last_12m                               0
# acc_open_past_24mths                       0
# avg_cur_bal                                3
# bc_open_to_buy                           643
# bc_util                                  667
# chargeoff_within_12_mths                   0
# delinq_amnt                                0
# mo_sin_old_il_acct                      1234
# mo_sin_old_rev_tl_op                       0
# mo_sin_rcnt_rev_tl_op                      0
# mo_sin_rcnt_tl                             0
# mort_acc                                   0
# mths_since_recent_bc                     597
# mths_since_recent_bc_dlq               29995
# mths_since_recent_inq                   3146
# mths_since_recent_revol_delinq         26574
# num_accts_ever_120_pd                      0
# num_actv_bc_tl                             0
# num_actv_rev_tl                            0
# num_bc_sats                                0
# num_bc_tl                                  0
# num_il_tl                                  0
# num_op_rev_tl                              0
# num_rev_accts                              0
# num_rev_tl_bal_gt_0                        0
# num_sats                                   0
# num_tl_120dpd_2m                        1010
# num_tl_30dpd                               0
# num_tl_90g_dpd_24m                         0
# num_tl_op_past_12m                         0
# pct_tl_nvr_dlq                             1
# percent_bc_gt_75                         643
# pub_rec_bankruptcies                       0
# tax_liens                                  0
# tot_hi_cred_lim                            0
# total_bal_ex_mort                          0
# total_bc_limit                             0
# total_il_high_credit_limit                 0
# revol_bal_joint                        33007
# sec_app_earliest_cr_line               33007
# sec_app_inq_last_6mths                 33007
# sec_app_mort_acc                       33007
# sec_app_open_acc                       33007
# sec_app_revol_util                     33106
# sec_app_open_act_il                    33007
# sec_app_num_rev_accts                  33007
# sec_app_chargeoff_within_12_mths       33007
# sec_app_collections_12_mths_ex_med     33007
# sec_app_mths_since_last_major_derog    36077
# disbursement_method                        0
# dtype: int64

# %%
X_train.head()
# Out:
#       id  member_id  loan_amnt  funded_amnt        term int_rate  installment  \
# 0  43373        NaN      12000        12000   36 months   16.02%       422.01
# 1  24414        NaN       6300         6300   36 months   14.07%       215.54
# 2  46723        NaN       4500         4500   36 months    7.21%       139.38
# 3  24878        NaN      12000        12000   36 months    9.44%       384.06
# 4  39038        NaN      12000        12000   36 months   22.35%       460.47
#
#   grade sub_grade                    emp_title emp_length home_ownership  \
# 0     C        C5                       Driver    4 years       MORTGAGE
# 1     C        C3                     GMP Lead    4 years           RENT
# 2     A        A3                    Accounts     3 years           RENT
# 3     B        B1  Client Processing Associate  10+ years       MORTGAGE
# 4     D        D5       Construction Operator   10+ years       MORTGAGE
#
#    annual_inc  url  desc             purpose               title zip_code  \
# 0     81000.0  NaN   NaN  debt_consolidation  Debt consolidation    280xx
# 1     39000.0  NaN   NaN  debt_consolidation  Debt consolidation    920xx
# 2     78000.0  NaN   NaN  debt_consolidation  Debt consolidation    906xx
# 3     62000.0  NaN   NaN  debt_consolidation  Debt consolidation    441xx
# 4     70000.0  NaN   NaN  debt_consolidation  Debt consolidation    751xx
#
#   addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  \
# 0         NC  12.76            0         Dec-2005               1
# 1         CA  21.42            0         Mar-2012               1
# 2         CA   2.17            0         May-2000               2
# 3         OH  13.76            0         Feb-2003               0
# 4         TX  14.04            4         Nov-2001               2
#
#    mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  \
# 0                    48.0                     NaN         7        0
# 1                     NaN                     NaN        10        0
# 2                     NaN                     NaN        13        0
# 3                     NaN                     NaN        22        0
# 4                    13.0                     NaN        18        0
#
#    revol_bal revol_util  total_acc initial_list_status  \
# 0       4912      23.5%         15                   w
# 1      11876      59.4%         12                   w
# 2       1715       5.2%         19                   w
# 3       9404      16.3%         33                   w
# 4      17895      24.2%         45                   w
#
#    collections_12_mths_ex_med  mths_since_last_major_derog application_type  \
# 0                           0                         48.0       Individual
# 1                           0                          NaN       Individual
# 2                           0                          NaN       Individual
# 3                           0                          NaN       Individual
# 4                           0                         13.0       Individual
#
#    annual_inc_joint  dti_joint  acc_now_delinq  tot_coll_amt  tot_cur_bal  \
# 0               NaN        NaN               0             0       174783
# 1               NaN        NaN               0             0        31046
# 2               NaN        NaN               0             0        35329
# 3               NaN        NaN               0             0        75160
# 4               NaN        NaN               0          7218       113702
#
#    open_acc_6m  open_act_il  open_il_12m  open_il_24m  mths_since_rcnt_il  \
# 0            1            2            0            4                13.0
# 1            0            1            0            2                14.0
# 2            0            8            1            2                10.0
# 3            4            1            0            2                13.0
# 4            9            2            2            4                 6.0
#
#    total_bal_il  il_util  open_rv_12m  open_rv_24m  max_bal_bc  all_util  \
# 0         33668     82.0            2            5        2962      63.0
# 1         19170     83.0            3            8        5153      72.0
# 2         33614    106.0            1            1        1196      54.0
# 3         17123     67.0            6            9        6898      32.0
# 4         16711     68.0            9           10        5373      35.0
#
#    total_rev_hi_lim  inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  \
# 0             20900       1            1             2                     9
# 1             20000       1            0             1                    10
# 2             33300       4            0             3                     3
# 3             57600       3            1             2                    12
# 4             73900       3            6             3                    14
#
#    avg_cur_bal  bc_open_to_buy  bc_util  chargeoff_within_12_mths  \
# 0      24969.0           588.0     89.3                         0
# 1       3105.0          6877.0     59.3                         0
# 2       2718.0         21585.0      7.4                         0
# 3       3579.0         33602.0     17.0                         0
# 4       6317.0         32863.0     24.1                         0
#
#    delinq_amnt  mo_sin_old_il_acct  mo_sin_old_rev_tl_op  \
# 0            0               145.0                    23
# 1            0                17.0                    72
# 2            0               166.0                   218
# 3            0               162.0                   179
# 4            0               159.0                   201
#
#    mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 0                      1               1         1                   8.0
# 1                      8               8         0                   8.0
# 2                     10              10         0                  31.0
# 3                      1               1         1                   1.0
# 4                      0               0         1                   0.0
#
#    mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                       NaN                    1.0
# 1                       NaN                    6.0
# 2                       NaN                    1.0
# 3                       NaN                    5.0
# 4                      62.0                    3.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                             NaN                      2               2
# 1                             NaN                      0               6
# 2                             NaN                      0               3
# 3                             NaN                      0               1
# 4                            62.0                      6               9
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                2            2          2          9              4
# 1                7            7          8          2              9
# 2                3            3          4         13              5
# 3                3            9         13          7             20
# 4               11           11         14         22             15
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0              5                    2         7               0.0
# 1             10                    7        10               0.0
# 2              6                    3        13               0.0
# 3             25                    3        22               0.0
# 4             20                   11        18               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0             0                   0                   2            92.9
# 1             0                   0                   3           100.0
# 2             0                   0                   2           100.0
# 3             0                   0                   7           100.0
# 4             0                   2                  11            82.2
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0             100.0                     0          0           206618
# 1              42.9                     0          0            43140
# 2               0.0                     0          0            65092
# 3               0.0                     0          0           133065
# 4               9.1                     0          0           192842
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0              38580            5500                       40863
# 1              31046           16900                       23140
# 2              35329           23300                       31792
# 3              26527           40500                       25465
# 4              34606           43300                       24499
#
#    revol_bal_joint sec_app_earliest_cr_line  sec_app_inq_last_6mths  \
# 0              NaN                      NaN                     NaN
# 1              NaN                      NaN                     NaN
# 2              NaN                      NaN                     NaN
# 3              NaN                      NaN                     NaN
# 4              NaN                      NaN                     NaN
#
#    sec_app_mort_acc  sec_app_open_acc  sec_app_revol_util  \
# 0               NaN               NaN                 NaN
# 1               NaN               NaN                 NaN
# 2               NaN               NaN                 NaN
# 3               NaN               NaN                 NaN
# 4               NaN               NaN                 NaN
#
#    sec_app_open_act_il  sec_app_num_rev_accts  \
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
#    sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#    sec_app_mths_since_last_major_derog disbursement_method
# 0                                  NaN                Cash
# 1                                  NaN                Cash
# 2                                  NaN                Cash
# 3                                  NaN                Cash
# 4                                  NaN                Cash

# %%
"""
member_id                              37745
emp_title                               3565
emp_length                              3277
url                                    37745
desc                                   37745
dti                                       92
mths_since_last_delinq                 20881
mths_since_last_record                 32170
revol_util                                53
mths_since_last_major_derog            28640
annual_inc_joint                       33007
dti_joint                              33007
mths_since_rcnt_il                      1234
il_util                                 6255
all_util                                  13
avg_cur_bal                                3
bc_open_to_buy                           643
bc_util                                  667
mo_sin_old_il_acct                      1234
mths_since_recent_bc                     597
mths_since_recent_bc_dlq               29995
mths_since_recent_inq                   3146
mths_since_recent_revol_delinq         26574
num_tl_120dpd_2m                        1010
pct_tl_nvr_dlq                             1
percent_bc_gt_75                         643
revol_bal_joint                        33007
sec_app_earliest_cr_line               33007
sec_app_inq_last_6mths                 33007
sec_app_mort_acc                       33007
sec_app_open_acc                       33007
sec_app_revol_util                     33106
sec_app_open_act_il                    33007
sec_app_num_rev_accts                  33007
sec_app_chargeoff_within_12_mths       33007
sec_app_collections_12_mths_ex_med     33007
sec_app_mths_since_last_major_derog    36077
"""
# Out:
# '\nmember_id                              37745\nemp_title                               3565\nemp_length                              3277\nurl                                    37745\ndesc                                   37745\ndti                                       92\nmths_since_last_delinq                 20881\nmths_since_last_record                 32170\nrevol_util                                53\nmths_since_last_major_derog            28640\nannual_inc_joint                       33007\ndti_joint                              33007\nmths_since_rcnt_il                      1234\nil_util                                 6255\nall_util                                  13\navg_cur_bal                                3\nbc_open_to_buy                           643\nbc_util                                  667\nmo_sin_old_il_acct                      1234\nmths_since_recent_bc                     597\nmths_since_recent_bc_dlq               29995\nmths_since_recent_inq                   3146\nmths_since_recent_revol_delinq         26574\nnum_tl_120dpd_2m                        1010\npct_tl_nvr_dlq                             1\npercent_bc_gt_75                         643\nrevol_bal_joint                        33007\nsec_app_earliest_cr_line               33007\nsec_app_inq_last_6mths                 33007\nsec_app_mort_acc                       33007\nsec_app_open_acc                       33007\nsec_app_revol_util                     33106\nsec_app_open_act_il                    33007\nsec_app_num_rev_accts                  33007\nsec_app_chargeoff_within_12_mths       33007\nsec_app_collections_12_mths_ex_med     33007\nsec_app_mths_since_last_major_derog    36077\n'

# %%
# Feature Engineering

def feature_engineering(df_input):
  
  df = df_input.copy()
  
  df.drop(columns=['id',
                'member_id',              
                'url',                                
                'desc',                               
                'mths_since_last_delinq',             
                'mths_since_last_record',             
                'mths_since_last_major_derog',        
                'annual_inc_joint',                   
                'dti_joint',                          
                'il_util',                            
                'mths_since_recent_bc_dlq',           
                'mths_since_recent_revol_delinq',     
                'revol_bal_joint',                    
                'sec_app_earliest_cr_line',           
                'sec_app_inq_last_6mths',             
                'sec_app_mort_acc',                   
                'sec_app_open_acc',                   
                'sec_app_revol_util',                 
                'sec_app_open_act_il',                
                'sec_app_num_rev_accts',              
                'sec_app_chargeoff_within_12_mths',   
                'sec_app_collections_12_mths_ex_med', 
                'sec_app_mths_since_last_major_derog',
                'num_tl_120dpd_2m', # No variance
                'emp_title',        # 16270 unique values
                #'zip_code',         # 855 unique values
                #'earliest_cr_line', # 596 unique values
               ], inplace=True)
  
  # term	- Convert to int
  def term_to_int(term_str):
    return int(term_str.replace(" months",""))
  
  df['term'] = df['term'].apply(term_to_int)

  # int_rate - Convert to float
  def int_rate_to_float(int_rate_str):
    return float(int_rate_str.replace("%",""))
  
  df['int_rate'] = df['int_rate'].apply(int_rate_to_float)

  # emp_length - Fill NA as Unknown and use encoding
  df['emp_length'].fillna("Unknown", inplace=True)

  # dti - Fill NA as 0.00
  df['dti'].fillna(0.00, inplace=True)

  # revol_util - Convert to float
  df['revol_util'].fillna("0.00%", inplace=True)

  def revol_util_to_float(revol_util_str):
    return float(revol_util_str.replace("%",""))

  df['revol_util'] = df['revol_util'].apply(revol_util_to_float)


  # mths_since_rcnt_il - Fill NA with mean
  df['mths_since_rcnt_il'].fillna(df['mths_since_rcnt_il'].mean(), 
                                     inplace=True)


  # all_util - Fill NA with mean
  df['all_util'].fillna(df['all_util'].mean(), inplace=True)


  # bc_open_to_buy - Fill NA with mean
  df['bc_open_to_buy'].fillna(df['bc_open_to_buy'].median(), 
                                 inplace=True)

  # bc_util - Fill NA with mean
  df['bc_util'].fillna(df['bc_util'].mean(), inplace=True)

  # mo_sin_old_il_acct - Fill NA with mean
  df['mo_sin_old_il_acct'].fillna(df['mo_sin_old_il_acct'].mean(), 
                                     inplace=True)

  # mths_since_recent_bc - Fill NA with mean
  df['mths_since_recent_bc'].fillna(df['mths_since_recent_bc'].mean(), 
                                 inplace=True)

  # mths_since_recent_inq - Fill NA with mean
  df['mths_since_recent_inq'].fillna(df['mths_since_recent_inq'].mean(), 
                                  inplace=True)

  # avg_cur_bal - Fill NA with mean
  df['avg_cur_bal'].fillna(df['avg_cur_bal'].mean(), 
                                  inplace=True)

  # pct_tl_nvr_dlq - Fill NA with mean
  df['pct_tl_nvr_dlq'].fillna(df['pct_tl_nvr_dlq'].mean(), 
                                  inplace=True)

  # percent_bc_gt_75 - Fill NA with mean
  df['percent_bc_gt_75'].fillna(df['percent_bc_gt_75'].mean(), 
                                  inplace=True)
  
  return df

# %%
X_train = feature_engineering(X_train)

# %%
import category_encoders as ce
from sklearn.model_selection import cross_val_predict
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

"""pipeline = make_pipeline(
    ce.BinaryEncoder(), 
    DecisionTreeClassifier(max_depth=5)
)"""

pipeline = make_pipeline(
    ce.BinaryEncoder(), 
    RandomForestClassifier(
        n_estimators=100, 
        class_weight='balanced', 
        min_samples_leaf=0.005, 
        oob_score=True, 
        n_jobs=-1)
)

pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('binaryencoder', BinaryEncoder(cols=['grade', 'sub_grade', 'emp_length', 'home_ownership', 'purpose', 'title', 'zip_code', 'addr_state', 'earliest_cr_line', 'initial_list_status', 'application_type', 'disbursement_method'],
#        drop_invariant=False, handle_unknown='impute', impute_missing...mators=100, n_jobs=-1, oob_score=True, random_state=None,
#             verbose=0, warm_start=False))])

# %%
# Out-of-Bag estimated score
from sklearn.metrics import roc_auc_score

y_pred_proba = pipeline.named_steps['randomforestclassifier'].oob_decision_function_[:, 1]
print('ROC AUC, Out-of-Bag estimate:', roc_auc_score(y_train, y_pred_proba))
# Out:
# ROC AUC, Out-of-Bag estimate: 0.7235478109944842

# %%
X_test = pd.read_csv("test_features.csv")
X_test = feature_engineering(X_test)

# %%
# Use GridSearch CV for hyper parameter tuning

from sklearn.model_selection import GridSearchCV

param_grid = {
    'randomforestclassifier__n_estimators': [400, 500, 600],
    'randomforestclassifier__min_samples_leaf': [0.001, 0.002, 0.005]
}

gridsearch = GridSearchCV(pipeline, param_grid=param_grid, cv=3,
                         scoring='roc_auc', verbose=10)

gridsearch.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=400
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=400, score=0.7323670969615695, total=  30.2s
# [CV] randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=400
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   32.6s remaining:    0.0s
# [CV]  randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=400, score=0.7284591135594322, total=  27.9s
# [CV] randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=400
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.0min remaining:    0.0s
# [CV]  randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=400, score=0.7394913104576102, total=  27.5s
# [CV] randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=500
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  1.5min remaining:    0.0s
# [CV]  randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=500, score=0.733822982727219, total=  33.8s
# [CV] randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=500
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  2.1min remaining:    0.0s
# [CV]  randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=500, score=0.7285866988096912, total=  34.3s
# [CV] randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=500
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  2.8min remaining:    0.0s
# [CV]  randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=500, score=0.7403439263328605, total=  33.3s
# [CV] randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=600
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  3.4min remaining:    0.0s
# [CV]  randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=600, score=0.7337074034915898, total=  40.6s
# [CV] randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=600
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  4.1min remaining:    0.0s
# [CV]  randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=600, score=0.7287645327102098, total=  41.0s
# [CV] randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=600
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  4.8min remaining:    0.0s
# [CV]  randomforestclassifier__min_samples_leaf=0.001, randomforestclassifier__n_estimators=600, score=0.7405760368315557, total=  42.3s
# [CV] randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=400
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  5.6min remaining:    0.0s
# [CV]  randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=400, score=0.7297814329732011, total=  25.9s
# [CV] randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=400
# [CV]  randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=400, score=0.7248891433209323, total=  25.0s
# [CV] randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=400
# [CV]  randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=400, score=0.7387704084792331, total=  24.9s
# [CV] randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=500
# [CV]  randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=500, score=0.7297308135952982, total=  31.1s
# [CV] randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=500
# [CV]  randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=500, score=0.725397168251916, total=  31.1s
# [CV] randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=500
# [CV]  randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=500, score=0.7383822149987689, total=  30.7s
# [CV] randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=600
# [CV]  randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=600, score=0.7301265605209508, total=  37.6s
# [CV] randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=600
# [CV]  randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=600, score=0.7261125821512565, total=  37.5s
# [CV] randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=600
# [CV]  randomforestclassifier__min_samples_leaf=0.002, randomforestclassifier__n_estimators=600, score=0.7381815224938234, total=  37.9s
# [CV] randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=400
# [CV]  randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=400, score=0.7246481450061014, total=  20.9s
# [CV] randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=400
# [CV]  randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=400, score=0.7198991703937772, total=  21.4s
# [CV] randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=400
# [CV]  randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=400, score=0.7339566582734302, total=  20.8s
# [CV] randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=500
# [CV]  randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=500, score=0.7245176717984451, total=  25.8s
# [CV] randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=500
# [CV]  randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=500, score=0.7198789803048451, total=  25.6s
# [CV] randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=500
# [CV]  randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=500, score=0.7336656390364544, total=  25.9s
# [CV] randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=600
# [CV]  randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=600, score=0.7249125130095826, total=  31.6s
# [CV] randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=600
# [CV]  randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=600, score=0.7192799741002949, total=  30.6s
# [CV] randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=600
# [CV]  randomforestclassifier__min_samples_leaf=0.005, randomforestclassifier__n_estimators=600, score=0.7336323581167934, total=  31.8s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed: 14.9min finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('binaryencoder', BinaryEncoder(cols=['grade', 'sub_grade', 'emp_length', 'home_ownership', 'purpose', 'title', 'zip_code', 'addr_state', 'earliest_cr_line', 'initial_list_status', 'application_type', 'disbursement_method'],
#        drop_invariant=False, handle_unknown='impute', impute_missing...mators=100, n_jobs=-1, oob_score=True, random_state=None,
#             verbose=0, warm_start=False))]),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'randomforestclassifier__n_estimators': [400, 500, 600], 'randomforestclassifier__min_samples_leaf': [0.001, 0.002, 0.005]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=10)

# %%
# Best cross validation score
print('Cross Validation Score:', gridsearch.best_score_)

# Best parameters which resulted in the best score
print('Best Parameters:', gridsearch.best_params_)
# Out:
# Cross Validation Score: 0.7343492903308948
# Best Parameters: {'randomforestclassifier__min_samples_leaf': 0.001, 'randomforestclassifier__n_estimators': 600}

# %%
sample_submission = pd.read_csv('sample_submission.csv') 
submission = sample_submission.copy() 
submission['charged_off'] = gridsearch.predict_proba(X_test)[:, 1] 
submission.to_csv('submission-007.csv', index=False)

# %%
# !pip install eli5
# Out:
# Collecting eli5
#   Downloading https://files.pythonhosted.org/packages/8d/c8/04bed18dcce1d927b0dd5fc3425777354b714d2e62d60ae301928b5a5bf8/eli5-0.8.1-py2.py3-none-any.whl (98kB)
#     100% |████████████████████████████████| 102kB 2.7MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from eli5) (1.1.0)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from eli5) (1.14.6)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.6/dist-packages (from eli5) (0.20.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from eli5) (2.10)
# Requirement already satisfied: attrs>16.0.0 in /usr/local/lib/python3.6/dist-packages (from eli5) (19.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from eli5) (1.11.0)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.6/dist-packages (from eli5) (0.8.3)
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from eli5) (3.6.6)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (from eli5) (0.10.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->eli5) (1.1.1)
# Installing collected packages: eli5
# Successfully installed eli5-0.8.1

# %%
import eli5
from eli5.sklearn import PermutationImportance

encoder = ce.BinaryEncoder()
X_train_transformed = encoder.fit_transform(X_train)

model = RandomForestClassifier(
    n_estimators=600, 
    class_weight='balanced', 
    min_samples_leaf=0.001, 
    n_jobs=-1)

model.fit(X_train_transformed, y_train)
permuter = PermutationImportance(model, scoring='roc_auc', n_iter=3, cv='prefit')
permuter.fit(X_train_transformed, y_train)
# Out:
# PermutationImportance(cv='prefit',
#            estimator=RandomForestClassifier(bootstrap=True, class_weight='balanced',
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=0.001,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=600, n_jobs=-1, oob_score=False,
#             random_state=None, verbose=0, warm_start=False),
#            n_iter=3, random_state=None, refit=True, scoring='roc_auc')

# %%
eli5.show_weights(permuter, top=None, feature_names=X_train_transformed.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0314
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 int_rate
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0170
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 installment
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0164
#
#                     &plusmn; 0.0007
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dti
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0152
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 funded_amnt
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0148
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 loan_amnt
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0134
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 tot_hi_cred_lim
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0118
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 tot_cur_bal
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.23%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0113
#
#                     &plusmn; 0.0006
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 avg_cur_bal
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0113
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 grade_2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.53%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0108
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 num_il_tl
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0107
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 bc_open_to_buy
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0100
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 annual_inc
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0094
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 revol_util
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.39%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0094
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 bc_util
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0092
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mths_since_recent_inq
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.63%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0090
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 mort_acc
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.90%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0086
#
#                     &plusmn; 0.0001
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 home_ownership_1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.49%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0078
#
#                     &plusmn; 0.0001
