# %%
import pandas as pd

# %%
pd.read_csv("sample_submission.csv").charged_off.value_counts()
# Out:
# 0.5    9437
# Name: charged_off, dtype: int64

# %%
df = pd.read_csv('train_features.csv')

print(df.shape)

df.describe()
# Out:
# (37745, 103)
#                  id  member_id     loan_amnt   funded_amnt   installment  \
# count  37745.000000        0.0  37745.000000  37745.000000  37745.000000
# mean   33579.507193        NaN  14913.304411  14913.304411    444.702933
# std    13609.172414        NaN  10153.364841  10153.364841    293.571158
# min    10000.000000        NaN   1000.000000   1000.000000     30.120000
# 25%    21824.000000        NaN   7000.000000   7000.000000    222.990000
# 50%    33603.000000        NaN  12000.000000  12000.000000    361.500000
# 75%    45357.000000        NaN  20000.000000  20000.000000    610.170000
# max    57181.000000        NaN  40000.000000  40000.000000   1587.230000
#
#          annual_inc  url  desc           dti   delinq_2yrs  ...  \
# count  3.774500e+04  0.0   0.0  37653.000000  37745.000000  ...
# mean   7.962921e+04  NaN   NaN     18.508652      0.236111  ...
# std    8.052291e+04  NaN   NaN     19.670753      0.749590  ...
# ...

# %%
def clean(dat: pd.DataFrame) -> pd.DataFrame: 
    return (dat.dropna(axis=1)
           .assign(int_rate = dat.int_rate.apply(lambda s: float(s[:-1]))))

df = clean(pd.read_csv('train_features.csv'))

df.head()
# Out:
#       id  loan_amnt  funded_amnt        term  int_rate  installment grade  \
# 0  43373      12000        12000   36 months     16.02       422.01     C
# 1  24414       6300         6300   36 months     14.07       215.54     C
# 2  46723       4500         4500   36 months      7.21       139.38     A
# 3  24878      12000        12000   36 months      9.44       384.06     B
# 4  39038      12000        12000   36 months     22.35       460.47     D
#
#   sub_grade home_ownership  annual_inc  ... num_tl_30dpd num_tl_90g_dpd_24m  \
# 0        C5       MORTGAGE     81000.0  ...            0                  0
# 1        C3           RENT     39000.0  ...            0                  0
# 2        A3           RENT     78000.0  ...            0                  0
# 3        B1       MORTGAGE     62000.0  ...            0                  0
# 4        D5       MORTGAGE     70000.0  ...            0                  2
#
# ...

# %%
#df.delinq_2yrs.value_counts()

# %%
df.columns
# Out:
# Index(['id', 'loan_amnt', 'funded_amnt', 'term', 'int_rate', 'installment',
#        'grade', 'sub_grade', 'home_ownership', 'annual_inc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'delinq_2yrs', 'earliest_cr_line',
#        'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal', 'total_acc',
#        'initial_list_status', 'collections_12_mths_ex_med', 'application_type',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'total_bal_il',
#        'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'total_rev_hi_lim',
#        'inq_fi', 'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_rev_tl_op',
#        'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mort_acc',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
# ...
