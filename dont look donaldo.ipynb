# %%
import pandas as pd
import numpy as np
import eli5
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
import category_encoders as ce
pd.options.display.max_columns=(999)
pd.options.display.max_rows=(999)

# %%
train = pd.read_csv('train_features.csv')
train_labels = pd.read_csv('train_labels.csv')
test = pd.read_csv('test_features.csv')
sample_submission = pd.read_csv('sample_submission.csv')
print(train.shape, train_labels.shape, test.shape)
# Out:
# (1309457, 103) (1309457, 2) (26724, 103)

# %%
X_train = train
y_train = train_labels['charged_off']
X_test = test

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
import xgboost as xgb

def wrangle(X):
    
    X = X.copy()
    
    def remove_months(string):
        return int(string.strip(' months'))

    def remove_percent(string):
        if string == str:
            return float(string.strip(' %'))
        elif string == float:
            return float(string)
        elif string == int:
            return int(string)

    def remove_years(string):
        if "< 1 year" in string:
            return float(string.replace('< 1 year',0.5))
        elif "10+ years" in string:
            return float(string.replace('10+ years', 10.0))
        else:
            return float(string.strip(' years'))

    def remove_first4char(string):
        return int(string[4:])

    def wrangle_sub_grade(x):
        first_digit = ord(x[0]) - 64
        second_digit = int(x[1])
        return first_digit + second_digit/10
    
    # Drop some columns
    X = X.drop(columns='id')  # id is random
    X = X.drop(columns=['member_id', 'url', 'desc'])  # All null
    X = X.drop(columns='title')  # Duplicative of purpose
    X = X.drop(columns='grade')  # Duplicative of sub_grade
    
    # Transform sub_grade from "A1" - "G5" to 1.1 - 7.5
    def wrangle_sub_grade(x):
        first_digit = ord(x[0]) - 64
        second_digit = int(x[1])
        return first_digit + second_digit/10
    
    X['sub_grade'] = X['sub_grade'].apply(wrangle_sub_grade)

    # Convert percentages from strings to floats
    X['int_rate'] = X['int_rate'].str.strip('%').astype(float)
    X['revol_util'] = X['revol_util'].str.strip('%').astype(float)
        
    # Transform earliest_cr_line to an integer: how many days it's been open
    X['earliest_cr_line'] = pd.to_datetime(X['earliest_cr_line'], infer_datetime_format=True)
    X['earliest_cr_line'] = pd.Timestamp.today() - X['earliest_cr_line']
    X['earliest_cr_line'] = X['earliest_cr_line'].dt.days
    
    # Create features for three employee titles: teacher, manager, owner
    X['emp_title'] = X['emp_title'].str.lower()
    X['emp_title_teacher'] = X['emp_title'].str.contains('teacher', na=False)
    X['emp_title_manager'] = X['emp_title'].str.contains('manager', na=False)
    X['emp_title_owner']   = X['emp_title'].str.contains('owner', na=False)
    
    # Drop categoricals with high cardinality
    X = X.drop(columns=['emp_title', 'zip_code'])
    
    # Transform features with many nulls to binary flags
    many_nulls = ['sec_app_mths_since_last_major_derog',
                  'sec_app_revol_util',
                  'sec_app_earliest_cr_line',
                  'sec_app_mort_acc',
                  'dti_joint',
                  'sec_app_collections_12_mths_ex_med',
                  'sec_app_chargeoff_within_12_mths',
                  'sec_app_num_rev_accts',
                  'sec_app_open_act_il',
                  'sec_app_open_acc',
                  'revol_bal_joint',
                  'annual_inc_joint',
                  'sec_app_inq_last_6mths',
                  'mths_since_last_record',
                  'mths_since_recent_bc_dlq',
                  'mths_since_last_major_derog',
                  'mths_since_recent_revol_delinq',
                  'mths_since_last_delinq',
                  'il_util',
                  'emp_length',
                  'mths_since_recent_inq',
                  'mo_sin_old_il_acct',
                  'mths_since_rcnt_il',
                  'num_tl_120dpd_2m',
                  'bc_util',
                  'percent_bc_gt_75',
                  'bc_open_to_buy',
                  'mths_since_recent_bc']

    for col in many_nulls:
        X[col] = X[col].isnull()
    
    # For features with few nulls, do mean imputation
    for col in X:
        if X[col].isnull().sum() > 0:
            X[col] = X[col].fillna(X[col].mean())
    
    # Return the wrangled dataframe
    return X


X_train = wrangle(X_train)
X_test  = wrangle(X_test)
y_train = y_train
X_train.shape, X_test.shape
# Out:
# ((1309457, 98), (26724, 98))

# %%
encoder = ce.BinaryEncoder()
from sklearn.model_selection import train_test_split

X_train = encoder.fit_transform(X_train)
X_test = encoder.fit_transform(X_test)

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.23, stratify = y_train, random_state=420)

print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_val, label=y_val)
xgb_test = xgb.DMatrix(X_test)

print(xgb_test)
# Out:
# (1008281, 115) (301176, 115) (1008281,) (301176,)
# /Users/chrislouie/anaconda3/envs/data/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# <xgboost.core.DMatrix object at 0x12a587eb8>

# %%
params = {
        'booster' : 'dart',
        'objective' : 'binary:logistic',
        'rate_drop' : 0.1,
        'sample_type' : 'weighted',
        'learning_rate' : 0.1, 
        'min_child_weight' : 5,
        'max_depth' : 4,
        'gamma' : 0.2,
        'max_delta_step' : 1,
        'subsample' : 1,
        'colsample_bytree' : 0.4,
        'colsample_bylevel' : 1,
        'n_estimators' : 200,
        'alpha' : 0,
        'scale_pos_weight' : 1,
        'eval_metric' : "auc",
        'xgbclassifier__silent' : False,
        'n_jobs' : -1
}

num_rounds = 1000

evals = [(dtrain, 'train'), (dtest, 'validation')]

boost = xgb.train(params, dtrain, num_rounds, evals, early_stopping_rounds=50)
boost.save_model('DART_BABY_LETSGOOO.model')
# Out:
# [0]	train-auc:0.615469	validation-auc:0.5
# Multiple eval metrics have been passed: 'validation-auc' will be used for early stopping.
#
# Will train until validation-auc hasn't improved in 50 rounds.
# [1]	train-auc:0.640683	validation-auc:0.615213
# [2]	train-auc:0.66282	validation-auc:0.663398
# [3]	train-auc:0.68663	validation-auc:0.687086
# [4]	train-auc:0.688811	validation-auc:0.678506
# [5]	train-auc:0.695062	validation-auc:0.695453
# [6]	train-auc:0.696696	validation-auc:0.700926
# [7]	train-auc:0.70507	validation-auc:0.705324
# [8]	train-auc:0.705849	validation-auc:0.703998
# [9]	train-auc:0.706026	validation-auc:0.706371
# [10]	train-auc:0.706823	validation-auc:0.707792
# [11]	train-auc:0.707745	validation-auc:0.705528
# [12]	train-auc:0.708177	validation-auc:0.708624
# [13]	train-auc:0.70797	validation-auc:0.709395
# [14]	train-auc:0.709101	validation-auc:0.709669
# [15]	train-auc:0.709144	validation-auc:0.709961
# [16]	train-auc:0.709145	validation-auc:0.710321
# [17]	train-auc:0.710317	validation-auc:0.710775
# [82]	train-auc:0.715008	validation-auc:0.715315
# [83]	train-auc:0.714843	validation-auc:0.71568
# [84]	train-auc:0.715238	validation-auc:0.716011
# [85]	train-auc:0.715357	validation-auc:0.715494
# [86]	train-auc:0.715788	validation-auc:0.715546
# [87]	train-auc:0.715906	validation-auc:0.715316
# [88]	train-auc:0.715334	validation-auc:0.716047
# [89]	train-auc:0.716529	validation-auc:0.715183
# [90]	train-auc:0.716325	validation-auc:0.715117
# [91]	train-auc:0.716327	validation-auc:0.714898
# [92]	train-auc:0.715431	validation-auc:0.715586
# [93]	train-auc:0.715419	validation-auc:0.715691
# [94]	train-auc:0.715219	validation-auc:0.715455
# [95]	train-auc:0.715573	validation-auc:0.716519
# [96]	train-auc:0.715934	validation-auc:0.71583
# [97]	train-auc:0.715911	validation-auc:0.715397
# [98]	train-auc:0.715476	validation-auc:0.716225
# [99]	train-auc:0.715956	validation-auc:0.715408
# [100]	train-auc:0.716514	validation-auc:0.715817
# [101]	train-auc:0.716572	validation-auc:0.715496
# [102]	train-auc:0.715432	validation-auc:0.716061
# [103]	train-auc:0.716011	validation-auc:0.715511
# [104]	train-auc:0.715061	validation-auc:0.715216
# [105]	train-auc:0.715621	validation-auc:0.715788
# [106]	train-auc:0.715539	validation-auc:0.715428
# [107]	train-auc:0.715977	validation-auc:0.71597
# [108]	train-auc:0.716409	validation-auc:0.71627
# [109]	train-auc:0.716635	validation-auc:0.715764
# [110]	train-auc:0.716685	validation-auc:0.71515
# [111]	train-auc:0.71537	validation-auc:0.716189
# [112]	train-auc:0.716424	validation-auc:0.715542
# [113]	train-auc:0.716803	validation-auc:0.715746
# [114]	train-auc:0.717121	validation-auc:0.716552
# [115]	train-auc:0.715841	validation-auc:0.715809
# [116]	train-auc:0.716399	validation-auc:0.715605
# [117]	train-auc:0.716456	validation-auc:0.71643
# [118]	train-auc:0.716831	validation-auc:0.715738
# [119]	train-auc:0.716616	validation-auc:0.7155
# [120]	train-auc:0.716517	validation-auc:0.716202
# [121]	train-auc:0.716397	validation-auc:0.715643
# [122]	train-auc:0.715975	validation-auc:0.715477
# [123]	train-auc:0.716336	validation-auc:0.716256
# [124]	train-auc:0.716052	validation-auc:0.71582
# [125]	train-auc:0.716186	validation-auc:0.716035
# [126]	train-auc:0.715299	validation-auc:0.715493
# [127]	train-auc:0.716742	validation-auc:0.716132
# [128]	train-auc:0.716076	validation-auc:0.715519
# [129]	train-auc:0.716792	validation-auc:0.715566
# [130]	train-auc:0.716731	validation-auc:0.716416
# [131]	train-auc:0.715941	validation-auc:0.716818
# [132]	train-auc:0.71666	validation-auc:0.71681
# [133]	train-auc:0.716924	validation-auc:0.715671
# [134]	train-auc:0.71561	validation-auc:0.716757
# [135]	train-auc:0.716289	validation-auc:0.716115
# [136]	train-auc:0.716867	validation-auc:0.716078
# [137]	train-auc:0.716182	validation-auc:0.716028
# [138]	train-auc:0.716286	validation-auc:0.716119
# [139]	train-auc:0.716451	validation-auc:0.715997
# [140]	train-auc:0.716471	validation-auc:0.716835
# [141]	train-auc:0.717194	validation-auc:0.716122
# [142]	train-auc:0.715799	validation-auc:0.715867
# [143]	train-auc:0.716305	validation-auc:0.71611
# [144]	train-auc:0.715746	validation-auc:0.715655
# [145]	train-auc:0.716412	validation-auc:0.716344
# [146]	train-auc:0.71601	validation-auc:0.71682
# [147]	train-auc:0.71605	validation-auc:0.715655
# [148]	train-auc:0.716278	validation-auc:0.716129
# [149]	train-auc:0.716397	validation-auc:0.716929
# [150]	train-auc:0.717311	validation-auc:0.715959
# [151]	train-auc:0.716962	validation-auc:0.716683
# [152]	train-auc:0.716291	validation-auc:0.71572
# [153]	train-auc:0.716725	validation-auc:0.716583
# [154]	train-auc:0.716752	validation-auc:0.716474
# [155]	train-auc:0.716166	validation-auc:0.715579
# [156]	train-auc:0.716733	validation-auc:0.715989
# [157]	train-auc:0.717224	validation-auc:0.716374
# [158]	train-auc:0.715965	validation-auc:0.716401
# [159]	train-auc:0.717432	validation-auc:0.715936
# [160]	train-auc:0.716838	validation-auc:0.716702
# [161]	train-auc:0.716469	validation-auc:0.71688
# [162]	train-auc:0.716332	validation-auc:0.716437
# [163]	train-auc:0.716308	validation-auc:0.716719
# [164]	train-auc:0.716945	validation-auc:0.716509
# [165]	train-auc:0.716409	validation-auc:0.716389
# [166]	train-auc:0.716042	validation-auc:0.715407
# [167]	train-auc:0.716641	validation-auc:0.715631
# [168]	train-auc:0.716601	validation-auc:0.715954
# [169]	train-auc:0.716893	validation-auc:0.716194
# [170]	train-auc:0.71662	validation-auc:0.716813
# [171]	train-auc:0.716259	validation-auc:0.716657
# [172]	train-auc:0.71732	validation-auc:0.715427
# [173]	train-auc:0.716473	validation-auc:0.716768
# [174]	train-auc:0.717086	validation-auc:0.715961
# [175]	train-auc:0.717356	validation-auc:0.716584
# [176]	train-auc:0.716878	validation-auc:0.71618
# [177]	train-auc:0.716823	validation-auc:0.717109
# [178]	train-auc:0.716919	validation-auc:0.716532
# [179]	train-auc:0.716051	validation-auc:0.716196
# [180]	train-auc:0.716693	validation-auc:0.717004
# [181]	train-auc:0.717905	validation-auc:0.7166
# [182]	train-auc:0.716594	validation-auc:0.716517
# [183]	train-auc:0.717798	validation-auc:0.716322
# [184]	train-auc:0.717274	validation-auc:0.716426
# [185]	train-auc:0.717064	validation-auc:0.716776
# [186]	train-auc:0.716515	validation-auc:0.716926
# [187]	train-auc:0.716677	validation-auc:0.716934
# [188]	train-auc:0.716985	validation-auc:0.71691
# [189]	train-auc:0.717687	validation-auc:0.717203
# [190]	train-auc:0.717324	validation-auc:0.716637
# [191]	train-auc:0.717003	validation-auc:0.716505
# [192]	train-auc:0.717491	validation-auc:0.716642
# [193]	train-auc:0.716957	validation-auc:0.716527
# [194]	train-auc:0.716388	validation-auc:0.717262
# [195]	train-auc:0.71695	validation-auc:0.716417
# [196]	train-auc:0.716879	validation-auc:0.716293
# [197]	train-auc:0.717147	validation-auc:0.716405
# [198]	train-auc:0.717277	validation-auc:0.716722
# [199]	train-auc:0.716841	validation-auc:0.717021
# [200]	train-auc:0.717012	validation-auc:0.717055
# [201]	train-auc:0.717235	validation-auc:0.71651
# [202]	train-auc:0.717146	validation-auc:0.716835
# [203]	train-auc:0.716922	validation-auc:0.716247
# [204]	train-auc:0.717009	validation-auc:0.716919
# [205]	train-auc:0.716656	validation-auc:0.716892
# [206]	train-auc:0.717251	validation-auc:0.715451
# [207]	train-auc:0.717249	validation-auc:0.716646
# [208]	train-auc:0.717453	validation-auc:0.716824
# [209]	train-auc:0.716663	validation-auc:0.717202
# [210]	train-auc:0.717523	validation-auc:0.716705
# [211]	train-auc:0.717084	validation-auc:0.716523
# [212]	train-auc:0.716705	validation-auc:0.717538
# [213]	train-auc:0.717229	validation-auc:0.71715
# [214]	train-auc:0.71743	validation-auc:0.716486
# [215]	train-auc:0.717381	validation-auc:0.718021
# [216]	train-auc:0.717461	validation-auc:0.717018
# [217]	train-auc:0.71699	validation-auc:0.716609
# [218]	train-auc:0.717125	validation-auc:0.716531
# [219]	train-auc:0.717455	validation-auc:0.716402
# [220]	train-auc:0.717349	validation-auc:0.716817
# [221]	train-auc:0.717566	validation-auc:0.716293
# [222]	train-auc:0.717569	validation-auc:0.717778
# [223]	train-auc:0.717575	validation-auc:0.717003
# [224]	train-auc:0.717324	validation-auc:0.717324
# [225]	train-auc:0.717962	validation-auc:0.716705
# [226]	train-auc:0.716834	validation-auc:0.717224
# [227]	train-auc:0.717283	validation-auc:0.716821
# [228]	train-auc:0.71684	validation-auc:0.716609
# [229]	train-auc:0.717741	validation-auc:0.716871
# [230]	train-auc:0.717404	validation-auc:0.717075
# [231]	train-auc:0.716954	validation-auc:0.717108
# [232]	train-auc:0.716734	validation-auc:0.717105
# [233]	train-auc:0.717537	validation-auc:0.71743
# [234]	train-auc:0.717351	validation-auc:0.716233
# [235]	train-auc:0.717515	validation-auc:0.716906
# [236]	train-auc:0.717982	validation-auc:0.716391
# [237]	train-auc:0.717088	validation-auc:0.716204
# [238]	train-auc:0.717054	validation-auc:0.716621
# [239]	train-auc:0.717071	validation-auc:0.717233
# [240]	train-auc:0.71741	validation-auc:0.716942
# [241]	train-auc:0.71704	validation-auc:0.716591
# [242]	train-auc:0.71753	validation-auc:0.717469
# [243]	train-auc:0.7177	validation-auc:0.71613
# [244]	train-auc:0.717048	validation-auc:0.716603
# [245]	train-auc:0.716886	validation-auc:0.717396
# [246]	train-auc:0.716736	validation-auc:0.717016
# [247]	train-auc:0.716483	validation-auc:0.716817
# [248]	train-auc:0.717016	validation-auc:0.7166
# [249]	train-auc:0.718519	validation-auc:0.71674
# [250]	train-auc:0.717209	validation-auc:0.7169
# [251]	train-auc:0.717579	validation-auc:0.717129
# [252]	train-auc:0.717932	validation-auc:0.717567
# [253]	train-auc:0.716768	validation-auc:0.717412
# [254]	train-auc:0.716852	validation-auc:0.717576
# [255]	train-auc:0.717399	validation-auc:0.717808
# [256]	train-auc:0.716863	validation-auc:0.717298
# [257]	train-auc:0.717753	validation-auc:0.717347
# [258]	train-auc:0.717127	validation-auc:0.716925
# [259]	train-auc:0.716779	validation-auc:0.716381
# [260]	train-auc:0.7175	validation-auc:0.716728
# [261]	train-auc:0.716517	validation-auc:0.716849
# [262]	train-auc:0.717543	validation-auc:0.717078
# [263]	train-auc:0.716932	validation-auc:0.716738
# [264]	train-auc:0.717113	validation-auc:0.717701
# [265]	train-auc:0.717072	validation-auc:0.717401
# Stopping. Best iteration:
# [215]	train-auc:0.717381	validation-auc:0.718021

# %%
submission = sample_submission.copy()
preds = boost.predict(xgb_test, ntree_limit=boost.best_ntree_limit)
preds
# Out:
# array([0.11848793, 0.18083645, 0.14676853, ..., 0.11503875, 0.10629128,
#        0.29001722], dtype=float32)
