# %%
import pandas as pd
import numpy as np

df_sample = pd.read_csv("/Users/joshsolis/repos/joshdsolis/DS-Unit-4-Sprint-1-Tree-Ensembles/module1-decision-trees/ds1-tree-ensembles/sample_submission.csv")
df_train_f = pd.read_csv("/Users/joshsolis/repos/joshdsolis/DS-Unit-4-Sprint-1-Tree-Ensembles/module1-decision-trees/ds1-tree-ensembles/train_features.csv")
df_train_l = pd.read_csv("/Users/joshsolis/repos/joshdsolis/DS-Unit-4-Sprint-1-Tree-Ensembles/module1-decision-trees/ds1-tree-ensembles/train_labels.csv")

df_test = pd.read_csv("/Users/joshsolis/repos/joshdsolis/DS-Unit-4-Sprint-1-Tree-Ensembles/module1-decision-trees/ds1-tree-ensembles/test_features.csv")

# %%
train_objs_num = len(df_train_f)
dataset = pd.concat(objs=[df_train_f, df_test], axis=0).dropna(axis=1)

df_train_f_1 = dataset[:train_objs_num]
df_test_1 = dataset[train_objs_num:]

# %%
from sklearn.model_selection import train_test_split

X = df_train_f_1.dropna(axis=1)
y = df_train_l['charged_off']

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
pd.set_option('display.max_columns', None)


df_train_l.head()
# Out:
#       id  charged_off
# 0  43373            0
# 1  24414            0
# 2  46723            0
# 3  24878            0
# 4  39038            0

# %%
from sklearn.tree import DecisionTreeClassifier
import category_encoders as ce
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler


pipeline = make_pipeline(
    
    ce.OneHotEncoder(),
    DecisionTreeClassifier()
)

pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,y_pred)
# Out:
# 0.7841475045035499

# %%
y_pred = pipeline.predict(df_test.dropna(axis=1))

# %%
y_pred = pd.DataFrame(y_pred,index=None)

y_pred['id'] = df_test['id']
y_pred.rename(columns= {0 : 'charged_off'},inplace=True)
cols = ['id', 'charged_off']
y_pred = y_pred[cols]

y_pred.head()
# Out:
#       id  charged_off
# 0  57146            0
# 1  20988            0
# 2  10031            0
# 3  33892            0
# 4  35374            0

# %%
y_pred.to_csv('submit1', index=False)

# %%
df_train_f.head()
# Out:
#       id  member_id  loan_amnt  funded_amnt        term int_rate  installment  \
# 0  43373        NaN      12000        12000   36 months   16.02%       422.01
# 1  24414        NaN       6300         6300   36 months   14.07%       215.54
# 2  46723        NaN       4500         4500   36 months    7.21%       139.38
# 3  24878        NaN      12000        12000   36 months    9.44%       384.06
# 4  39038        NaN      12000        12000   36 months   22.35%       460.47
#
#   grade sub_grade                    emp_title emp_length home_ownership  \
# 0     C        C5                       Driver    4 years       MORTGAGE
# 1     C        C3                     GMP Lead    4 years           RENT
# 2     A        A3                    Accounts     3 years           RENT
# 3     B        B1  Client Processing Associate  10+ years       MORTGAGE
# 4     D        D5       Construction Operator   10+ years       MORTGAGE
#
# ...

# %%
df_train_f.dtypes
# Out:
# id                                       int64
# member_id                              float64
# loan_amnt                                int64
# funded_amnt                              int64
# term                                    object
# int_rate                                object
# installment                            float64
# grade                                   object
# sub_grade                               object
# emp_title                               object
# emp_length                              object
# home_ownership                          object
# annual_inc                             float64
# url                                    float64
# desc                                   float64
# purpose                                 object
# title                                   object
# zip_code                                object
# addr_state                              object
# dti                                    float64
# ...

# %%
df_train_f_2 = df_train_f
df_test_2 = df_test

def wrangle(dataset):
    # Drop some columns
    dataset = dataset.drop(columns='id')  # id is random
    dataset = dataset.drop(columns=['member_id', 'url', 'desc'])  # All null
    dataset = dataset.drop(columns='title')  # Duplicative of purpose
    dataset = dataset.drop(columns='grade')  # Duplicative of sub_grade
    dataset = dataset.drop(columns=['emp_title', 'zip_code'])
    
    # Transform sub_grade from "A1" - "G5" to 1.1 - 7.5
    def wrangle_sub_grade(dataset):
        first_digit = ord(dataset[0]) - 64
        second_digit = int(dataset[1])
        return first_digit + second_digit/10
    
    dataset['sub_grade'] = dataset['sub_grade'].apply(wrangle_sub_grade)
    # Making term column into an int dtype
    dataset['term'] = dataset.term.str.replace('months' , '')
    dataset['term'] = dataset['term'].astype(int)

    # Making int_rate column into float dtype
    dataset['int_rate'] = dataset.int_rate.str.replace('%' , '')
    dataset['int_rate'] = dataset['int_rate'].astype(float)

    # Making emp_length column into int dtype
    dataset['emp_length'] = dataset.emp_length.str.replace('years','')
    dataset['emp_length'] = dataset.emp_length.str.replace('+','')

    # Transform earliest_cr_line to an integer: how many days it's been open
    X['earliest_cr_line'] = pd.to_datetime(X['earliest_cr_line'], infer_datetime_format=True)
    X['earliest_cr_line'] = pd.Timestamp.today() - X['earliest_cr_line']
    X['earliest_cr_line'] = X['earliest_cr_line'].dt.days

    # Making revol_util into float dtype
    dataset['revol_util'] = dataset.revol_util.str.replace('%' , '')
    dataset['revol_util'] = dataset['revol_util'].astype(float)
    
    # Making new column for if they were delinq at all
    dataset['was_delinq'] = np.where(dataset.mths_since_last_delinq.isnull(), 0, 1)
    
    # Transform features with many nulls to binary flags
    many_nulls = ['sec_app_mths_since_last_major_derog',
                  'sec_app_revol_util',
                  'sec_app_earliest_cr_line',
                  'sec_app_mort_acc',
                  'dti_joint',
                  'sec_app_collections_12_mths_ex_med',
                  'sec_app_chargeoff_within_12_mths',
                  'sec_app_num_rev_accts',
                  'sec_app_open_act_il',
                  'sec_app_open_acc',
                  'revol_bal_joint',
                  'annual_inc_joint',
                  'sec_app_inq_last_6mths',
                  'mths_since_last_record',
                  'mths_since_recent_bc_dlq',
                  'mths_since_last_major_derog',
                  'mths_since_recent_revol_delinq',
                  'mths_since_last_delinq',
                  'il_util',
                  'emp_length',
                  'mths_since_recent_inq',
                  'mo_sin_old_il_acct',
                  'mths_since_rcnt_il',
                  'num_tl_120dpd_2m',
                  'bc_util',
                  'percent_bc_gt_75',
                  'bc_open_to_buy',
                  'mths_since_recent_bc']

    for col in many_nulls:
        dataset[col] = dataset[col].isnull()
    
    # For features with few nulls, do mean imputation
    for col in dataset:
        if dataset[col].isnull().sum() > 0:
            dataset[col] = dataset[col].fillna(dataset[col].mean())
    
    dataset['int_amt'] = dataset['int_rate']*(dataset['loan_amnt']+ dataset['funded_amnt'])
    
    return dataset

df_train_f_2 = wrangle(df_train_f_2).dropna(axis=1)
df_test_2 = wrangle(df_test_2).dropna(axis=1)
df_train_f_2.head()
# Out:
#    loan_amnt  funded_amnt  term  int_rate  installment  sub_grade  emp_length  \
# 0      12000        12000    36     16.02       422.01        3.5       False
# 1       6300         6300    36     14.07       215.54        3.3       False
# 2       4500         4500    36      7.21       139.38        1.3       False
# 3      12000        12000    36      9.44       384.06        2.1       False
# 4      12000        12000    36     22.35       460.47        4.5       False
#
#   home_ownership  annual_inc             purpose addr_state    dti  \
# 0       MORTGAGE     81000.0  debt_consolidation         NC  12.76
# 1           RENT     39000.0  debt_consolidation         CA  21.42
# 2           RENT     78000.0  debt_consolidation         CA   2.17
# 3       MORTGAGE     62000.0  debt_consolidation         OH  13.76
# 4       MORTGAGE     70000.0  debt_consolidation         TX  14.04
#
#    delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  \
# ...

# %%
df_train_f_2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37745 entries, 0 to 37744
# Data columns (total 96 columns):
# loan_amnt                              37745 non-null int64
# funded_amnt                            37745 non-null int64
# term                                   37745 non-null int64
# int_rate                               37745 non-null float64
# installment                            37745 non-null float64
# sub_grade                              37745 non-null float64
# emp_length                             37745 non-null bool
# home_ownership                         37745 non-null object
# annual_inc                             37745 non-null float64
# purpose                                37745 non-null object
# addr_state                             37745 non-null object
# dti                                    37745 non-null float64
# delinq_2yrs                            37745 non-null int64
# ...

# %%
from sklearn.model_selection import train_test_split

X = df_train_f_2
y = df_train_l['charged_off']

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import category_encoders as ce
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score


pipeline = make_pipeline(
    
    ce.OneHotEncoder(),
    RandomForestClassifier(n_estimators=300, 
                           class_weight='balanced', 
                           min_samples_leaf=0.005, 
                           oob_score=True, 
                           n_jobs=-1)
)

pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
#cross_val_score(pipeline, X_train, y_train, cv=5, scoring='roc_auc', verbose=10)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6662074811910564

# %%
y_pred = pipeline.predict(df_test_2.dropna(axis=1))

y_pred = pd.DataFrame(y_pred,index=None)

y_pred['id'] = df_test['id']
y_pred.rename(columns= {0 : 'charged_off'},inplace=True)
cols = ['id', 'charged_off']
y_pred = y_pred[cols]

y_pred.head()
# Out:
#       id  charged_off
# 0  57146            1
# 1  20988            1
# 2  10031            0
# 3  33892            0
# 4  35374            0

# %%
y_pred.to_csv('submit5', index=False)

# %%
df_train_f.isna().sum()
# Out:
# id                                         0
# member_id                              37745
# loan_amnt                                  0
# funded_amnt                                0
# term                                       0
# int_rate                                   0
# installment                                0
# grade                                      0
# sub_grade                                  0
# emp_title                               3565
# emp_length                              3277
# home_ownership                             0
# annual_inc                                 0
# url                                    37745
# desc                                   37745
# purpose                                    0
# title                                      0
# zip_code                                   0
# addr_state                                 0
# dti                                       92
# delinq_2yrs                                0
# ...

# %%
df_train_f.shape
# Out:
# (37745, 103)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import category_encoders as ce
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV


param_grid = {
     'n_estimators':[100,200,500,1000,2000],
     'min_samples_leaf':[.001,.002,.005,.01,.1],
}

pipeline = make_pipeline(
    
    ce.OneHotEncoder(),
    GridSearchCV(RandomForestClassifier(), scoring='accuracy', param_grid=param_grid, cv=3, verbose=10)

)

pipeline.fit(X_train, y_train)
y_pred = pipeline.predict(X_test)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV] min_samples_leaf=0.001, n_estimators=100 ........................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  min_samples_leaf=0.001, n_estimators=100, score=0.8532217041119118, total=   6.4s
# [CV] min_samples_leaf=0.001, n_estimators=100 ........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.8s remaining:    0.0s
# [CV]  min_samples_leaf=0.001, n_estimators=100, score=0.8532217041119118, total=   7.8s
# [CV] min_samples_leaf=0.001, n_estimators=100 ........................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   17.0s remaining:    0.0s
# [CV]  min_samples_leaf=0.001, n_estimators=100, score=0.8532217041119118, total=   6.3s
# [CV] min_samples_leaf=0.001, n_estimators=200 ........................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   24.4s remaining:    0.0s
# ...

# %%
# %%time
import eli5
from eli5.sklearn import PermutationImportance

encoder = ce.OrdinalEncoder()
X_train_transformed = encoder.fit_transform(X_train)

model = RandomForestClassifier(
    n_estimators=100, 
    class_weight='balanced', 
    min_samples_leaf=0.005, 
    n_jobs=-1)

model.fit(X_train_transformed, y_train)
permuter = PermutationImportance(model, scoring='roc_auc', n_iter=1, cv='prefit')
permuter.fit(X_train_transformed, y_train)
# Out:
# CPU times: user 40.9 s, sys: 1.27 s, total: 42.1 s
# Wall time: 16.5 s

# %%
eli5.show_weights(permuter, top=None, feature_names=X_train_transformed.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0194
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 sub_grade
#             </td>
# ...
